# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('housing.csv')

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# Removing null values
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
# Training data
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3799     -118.36     34.16                45.0       1755.0           335.0
# 16554    -121.30     37.85                35.0       1034.0           206.0
# 16680    -120.59     35.13                 8.0       6638.0          1054.0
# 5107     -118.31     33.94                43.0       2104.0           393.0
# 13406    -117.46     34.09                 8.0       4711.0           963.0
# ...          ...       ...                 ...          ...             ...
# 1953     -120.78     38.74                28.0       4236.0           877.0
# 343      -122.19     37.75                36.0       1126.0           263.0
# 10620    -117.82     33.67                17.0       2895.0           439.0
# 17407    -120.45     34.94                24.0       1702.0           447.0
# 11479    -118.02     33.73                24.0       6393.0          1141.0
#
# ...

# %%
train_data.hist(figsize=(17, 8))
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924462           -0.113864     0.047844
# latitude            -0.924462  1.000000            0.014336    -0.036930
# housing_median_age  -0.113864  0.014336            1.000000    -0.362167
# total_rooms          0.047844 -0.036930           -0.362167     1.000000
# total_bedrooms       0.071992 -0.067598           -0.322215     0.930436
# population           0.102086 -0.110045           -0.294969     0.856273
# households           0.059385 -0.073051           -0.304243     0.918240
# median_income       -0.015233 -0.079029           -0.121594     0.197457
# median_house_value  -0.045782 -0.144258            0.105033     0.129820
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071992    0.102086    0.059385      -0.015233
# latitude                 -0.067598   -0.110045   -0.073051      -0.079029
# ...

# %%
plt.figure(figsize=(17,8))
sns.heatmap(train_data.corr(), annot=True, cmap='RdPu_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>Observing Corrrelations</h3>
#
# In this housing price dataset, I've observed strong positive correlations between the total number of rooms (total_rooms), total bedrooms (total_bedrooms), population, and households. This indicates that larger houses tend to have more bedrooms, accommodate more people, and house more households. These correlations can be valuable features for predicting housing prices, but it's crucial to be aware of potential multicollinearity issues due to their strong interrelatedness. Further analysis and modeling techniques may be needed to address these relationships and build accurate predictive models.

# %% [markdown]
# **Since the histograms we saw previosly were skewed, we can take the logarithms of the data to visualize them more accurately.**

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(17,8))
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     7189
# INLAND        5198
# NEAR OCEAN    2141
# NEAR BAY      1814
# ISLAND           4
# Name: ocean_proximity, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 3799           1       0       0         0           0
# 16554          0       1       0         0           0
# 16680          1       0       0         0           0
# 5107           1       0       0         0           0
# 13406          0       1       0         0           0
# ...          ...     ...     ...       ...         ...
# 1953           0       1       0         0           0
# 343            0       0       0         1           0
# 10620          1       0       0         0           0
# 17407          1       0       0         0           0
# 11479          1       0       0         0           0
#
# [16346 rows x 5 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3799     -118.36     34.16                45.0     7.470794        5.817111
# 16554    -121.30     37.85                35.0     6.942157        5.332719
# 16680    -120.59     35.13                 8.0     8.800717        6.961296
# 5107     -118.31     33.94                43.0     7.652071        5.976351
# 13406    -117.46     34.09                 8.0     8.457868        6.871091
# ...          ...       ...                 ...          ...             ...
# 1953     -120.78     38.74                28.0     8.351611        6.777647
# 343      -122.19     37.75                36.0     7.027315        5.575949
# 10620    -117.82     33.67                17.0     7.971086        6.086775
# 17407    -120.45     34.94                24.0     7.440147        6.104793
# 11479    -118.02     33.73                24.0     8.763115        7.040536
#
# ...

# %%
plt.figure(figsize=(17,8))
sns.heatmap(train_data.corr(), annot=True, cmap='RdPu_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **We can see here that there is a negative correlation with 'INLAND' and 'median_house_value' of -0.49. Houses near the ocean tend to command higher prices than those located inland primarily due to the strong positive correlation between coastal proximity and property values. We can visualize this with a scatterplot as shown below**

# %%
plt.figure(figsize=(17, 8))
sns.scatterplot(x='latitude', y='longitude', data=train_data, hue='median_house_value', palette='RdYlGn')
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# **We want to see if the bedroom ratio and the total household rooms would yield more interesting insights of their correlations to other attributes. Doing this shows us that there seems be some correlation with the bedroom ration and household rooms with population and median income.**

# %%
train_data['bedroom_ration'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(17,8))
sns.heatmap(train_data.corr(), annot=True, cmap='RdPu_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>Linear Regression:</h3>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler() # Scaling data

X_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ration'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
X_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
X_test_s = scaler.transform(X_test)

# %%
reg.score(X_test, y_test)
# Out:
# 0.6779274051870232

# %%
from sklearn.ensemble import RandomForestRegressor


forest = RandomForestRegressor()

forest.fit(X_train, y_train)
forest.score(X_test, y_test)
# Out:
# 0.8223873447906492

# %%
forest.fit(X_train_s, y_train)
forest.score(X_test_s, y_test)
# Out:
# 0.8218470044396258

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    'n_estimators': [5, 30, 50, 100],
    'max_features': [4, 6, 8, 20],
    'min_samples_split': [2, 4, 6, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5, scoring='neg_mean_squared_error', return_train_score=True)

grid_search.fit(X_train_s, y_train)

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test_s, y_test)
# Out:
# 0.8131101106782015
